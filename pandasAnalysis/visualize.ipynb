# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df =pd.read_csv('world_population.csv')

# %%
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0            %2f, %x          %2f, %x          %2f, %x          %2f, %x
# 1            %2f, %x          %2f, %x          %2f, %x          %2f, %x
# 2            %2f, %x          %2f, %x          %2f, %x          %2f, %x
# 3            %2f, %x          %2f, %x          %2f, %x          %2f, %x
# 4            %2f, %x          %2f, %x          %2f, %x          %2f, %x
# ..               ...              ...              ...              ...
# 229          %2f, %x          %2f, %x          %2f, %x          %2f, %x
# 230          %2f, %x          %2f, %x          %2f, %x          %2f, %x
# 231          %2f, %x          %2f, %x          %2f, %x          %2f, %x
# 232          %2f, %x          %2f, %x              NaN          %2f, %x
# 233          %2f, %x          %2f, %x          %2f, %x          %2f, %x
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# 0            %2f, %x          %2f, %x          %2f, %x          %2f, %x
# 1            %2f, %x          %2f, %x          %2f, %x          %2f, %x
# 2            %2f, %x          %2f, %x          %2f, %x          %2f, %x
# 3            %2f, %x          %2f, %x          %2f, %x          %2f, %x
# 4            %2f, %x          %2f, %x          %2f, %x          %2f, %x
# ..               ...              ...              ...              ...
# 229          %2f, %x          %2f, %x          %2f, %x          %2f, %x
# 230          %2f, %x          %2f, %x          %2f, %x          %2f, %x
# 231          %2f, %x          %2f, %x          %2f, %x          %2f, %x
# 232          %2f, %x          %2f, %x          %2f, %x          %2f, %x
# 233          %2f, %x          %2f, %x          %2f, %x          %2f, %x
#
#      Area (km²)  Density (per km²)  Growth Rate  World Population Percentage
# 0       %2f, %x            %2f, %x      %2f, %x                      %2f, %x
# 1       %2f, %x            %2f, %x      %2f, %x                      %2f, %x
# 2       %2f, %x            %2f, %x      %2f, %x                      %2f, %x
# 3       %2f, %x            %2f, %x      %2f, %x                      %2f, %x
# 4       %2f, %x            %2f, %x      %2f, %x                      %2f, %x
# ..          ...                ...          ...                          ...
# 229     %2f, %x            %2f, %x      %2f, %x                      %2f, %x
# 230     %2f, %x            %2f, %x      %2f, %x                      %2f, %x
# 231     %2f, %x            %2f, %x      %2f, %x                      %2f, %x
# 232     %2f, %x            %2f, %x      %2f, %x                      %2f, %x
# 233     %2f, %x            %2f, %x      %2f, %x                      %2f, %x
#
# [234 rows x 17 columns]

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0        41128771.00      38972230.00      33753499.00      28189672.00
# 1         2842321.00       2866849.00       2882481.00       2913399.00
# 2        44903225.00      43451666.00      39543154.00      35856344.00
# 3           44273.00         46189.00         51368.00         54849.00
# 4           79824.00         77700.00         71746.00         71519.00
# ..               ...              ...              ...              ...
# 229         11572.00         11655.00         12182.00         13142.00
# 230        575986.00        556048.00        491824.00        413296.00
# 231      33696614.00      32284046.00      28516545.00      24743946.00
# 232      20017675.00      18927715.00              NaN      13792086.00
# 233      16320537.00      15669666.00      14154937.00      12839771.00
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# 0        19542982.00      10694796.00      12486631.00      10752971.00
# 1         3182021.00       3295066.00       2941651.00       2324731.00
# 2        30774621.00      25518074.00      18739378.00      13795915.00
# 3           58230.00         47818.00         32886.00         27075.00
# 4           66097.00         53569.00         35611.00         19860.00
# ..               ...              ...              ...              ...
# 229         14723.00         13454.00         11315.00          9377.00
# 230        270375.00        178529.00        116775.00         76371.00
# 231      18628700.00      13375121.00       9204938.00       6843607.00
# 232       9891136.00       7686401.00       5720438.00       4281671.00
# 233      11834676.00      10113893.00       7049926.00       5202918.00
#
#      Area (km²)  Density (per km²)  Growth Rate  World Population Percentage
# 0     652230.00              63.06         1.03                         0.52
# 1      28748.00              98.87         1.00                         0.04
# 2    2381741.00              18.85         1.02                         0.56
# 3        199.00             222.48         0.98                         0.00
# 4        468.00             170.56         1.01                         0.00
# ..          ...                ...          ...                          ...
# 229      142.00              81.49         1.00                         0.00
# 230   266000.00               2.17         1.02                         0.01
# 231   527968.00              63.82         1.02                         0.42
# 232   752612.00              26.60         1.03                         0.25
# 233   390757.00              41.77         1.02                         0.20
#
# [234 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country                      234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              230 non-null    float64
#  6   2020 Population              233 non-null    float64
#  7   2015 Population              230 non-null    float64
#  8   2010 Population              227 non-null    float64
#  9   2000 Population              227 non-null    float64
#  10  1990 Population              229 non-null    float64
#  11  1980 Population              229 non-null    float64
#  12  1970 Population              230 non-null    float64
#  13  Area (km²)                   232 non-null    float64
#  14  Density (per km²)            230 non-null    float64
#  15  Growth Rate                  232 non-null    float64
#  16  World Population Percentage  234 non-null    float64
# dtypes: float64(12), int64(1), object(4)
# memory usage: 31.2+ KB

# %%
df.describe(include='all')
# Out:
#          Rank CCA3      Country Capital Continent  2022 Population  \
# count  234.00  234          234     234       234           230.00
# unique    NaN  234          234     234         6              NaN
# top       NaN  AFG  Afghanistan   Kabul    Africa              NaN
# freq      NaN    1            1       1        57              NaN
# mean   117.50  NaN          NaN     NaN       NaN      34632250.88
# std     67.69  NaN          NaN     NaN       NaN     137889172.44
# min      1.00  NaN          NaN     NaN       NaN           510.00
# 25%     59.25  NaN          NaN     NaN       NaN        419738.50
# 50%    117.50  NaN          NaN     NaN       NaN       5762857.00
# 75%    175.75  NaN          NaN     NaN       NaN      22653719.00
# max    234.00  NaN          NaN     NaN       NaN    1425887337.00
#
#         2020 Population  2015 Population  2010 Population  2000 Population  \
# count            233.00           230.00           227.00           227.00
# unique              NaN              NaN              NaN              NaN
# top                 NaN              NaN              NaN              NaN
# freq                NaN              NaN              NaN              NaN
# mean        33600710.95      32066004.16      30270164.48      26840495.26
# std        135873196.61     131507146.34     126074183.54     113352454.57
# min              520.00           564.00           596.00           651.00
# 25%           406471.00        394295.00        382726.50        329470.00
# 50%          5456681.00       5244415.00       4889741.00       4491202.00
# 75%         21522626.00      19730853.75      16825852.50      15625467.00
# max       1424929781.00    1393715448.00    1348191368.00    1264099069.00
#
#         1990 Population  1980 Population  1970 Population  Area (km²)  \
# count            229.00           229.00           230.00      232.00
# unique              NaN              NaN              NaN         NaN
# top                 NaN              NaN              NaN         NaN
# freq                NaN              NaN              NaN         NaN
# mean        19330463.93      16282884.78      15866499.13   581663.75
# std         81309624.96      69345465.54      68355859.75  1769133.06
# min              700.00           733.00           752.00        1.00
# 25%           261928.00        223752.00        145880.50     2567.25
# 50%          3785847.00       3135123.00       2511718.00    77141.00
# 75%         11882762.00       9817257.00       8817329.00   414643.25
# max       1153704252.00     982372466.00     822534450.00 17098242.00
#
#         Density (per km²)  Growth Rate  World Population Percentage
# count              230.00       232.00                       234.00
# unique                NaN          NaN                          NaN
# top                   NaN          NaN                          NaN
# freq                  NaN          NaN                          NaN
# mean               456.81         1.01                         0.43
# std               2083.74         0.01                         1.71
# min                  0.03         0.91                         0.00
# 25%                 36.60         1.00                         0.01
# 50%                 95.35         1.01                         0.07
# 75%                236.88         1.02                         0.28
# max              23172.27         1.07                        17.88

# %%
df.nunique()
# Out:
# Rank                           209
# CCA3                           209
# Country                        209
# Capital                        209
# Continent                        6
# 2022 Population                209
# 2020 Population                209
# 2015 Population                209
# 2010 Population                209
# 2000 Population                209
# 1990 Population                209
# 1980 Population                209
# 1970 Population                209
# Area (km²)                     208
# Density (per km²)              209
# Growth Rate                    163
# World Population Percentage     67
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Rank                           0
# CCA3                           0
# Country                        0
# Capital                        0
# Continent                      0
# 2022 Population                0
# 2020 Population                0
# 2015 Population                0
# 2010 Population                0
# 2000 Population                0
# 1990 Population                0
# 1980 Population                0
# 1970 Population                0
# Area (km²)                     0
# Density (per km²)              0
# Growth Rate                    0
# World Population Percentage    0
# dtype: int64

# %%
#df.dropna(inplace=True)
df.columns
# Out:
# Index(['Rank', 'CCA3', 'Country', 'Capital', 'Continent', '2022 Population',
#        '2020 Population', '2015 Population', '2010 Population',
#        '2000 Population', '1990 Population', '1980 Population',
#        '1970 Population', 'Area (km²)', 'Density (per km²)', 'Growth Rate',
#        'World Population Percentage'],
#       dtype='object')

# %%
df.sort_values(by='2022 Population',ascending=False).head()
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 41      1  CHN          China           Beijing           Asia
# 221     3  USA  United States  Washington, D.C.  North America
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 149     6  NGA        Nigeria             Abuja         Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41     1425887337.00    1424929781.00    1393715448.00    1348191368.00
# 221     338289857.00     335942003.00     324607776.00     311182845.00
# 93      275501339.00     271857970.00     259091970.00     244016173.00
# 156     235824862.00     227196741.00     210969298.00     194454498.00
# 149     218541212.00     208327405.00     183995785.00     160952853.00
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# 41     1264099069.00    1153704252.00     982372466.00     822534450.00
# 221     282398554.00     248083732.00     223140018.00     200328340.00
# 93      214072421.00     182159874.00     148177096.00     115228394.00
# 156     154369924.00     115414069.00      80624057.00      59290872.00
# 149     122851984.00      95214257.00      72951439.00      55569264.00
#
#      Area (km²)  Density (per km²)  Growth Rate  World Population Percentage
# 41   9706961.00             146.89         1.00                        17.88
# 221  9372610.00              36.09         1.00                         4.24
# 93   1904569.00             144.65         1.01                         3.45
# 156   881912.00             267.40         1.02                         2.96
# 149   923768.00             236.58         1.02                         2.74

# %%
df[df['CCA3'] =='AFG']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16220\3858329356.py in ?()
# ----> 1 df[df['CCA3'] =='AFG'].drop(axis=1)
#
# c:\Users\pacif\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py in ?(self, labels, axis, index, columns, level, inplace, errors)
#    5577                 weight  250.0   150.0
#    5578         falcon  speed   320.0   250.0
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#    5584             index=index,
#
# c:\Users\pacif\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, labels, axis, index, columns, level, inplace, errors)
#    4776             axes = {"index": index}
#    4777             if self.ndim == 2:
#    4778                 axes["columns"] = columns
#    4779         else:
# -> 4780             raise ValueError(
#    4781                 "Need to specify at least one of 'labels', 'index' or 'columns'"
#    4782             )
#    4783
#
# ValueError: Need to specify at least one of 'labels', 'index' or 'columns'

# %%
df_num=df.select_dtypes(include=[float, int])

# %%
df_num.corr()
# Out:
#                              Rank  2022 Population  2020 Population  \
# Rank                         1.00            -0.39            -0.38
# 2022 Population             -0.39             1.00             1.00
# 2020 Population             -0.38             1.00             1.00
# 2015 Population             -0.37             1.00             1.00
# 2010 Population             -0.37             1.00             1.00
# 2000 Population             -0.35             1.00             1.00
# 1990 Population             -0.34             0.99             0.99
# 1980 Population             -0.33             0.99             0.99
# 1970 Population             -0.33             0.98             0.98
# Area (km²)                  -0.38             0.52             0.52
# Density (per km²)            0.13            -0.04            -0.04
# Growth Rate                 -0.21            -0.01            -0.02
# World Population Percentage -0.39             1.00             1.00
#
#                              2015 Population  2010 Population  \
# Rank                                   -0.37            -0.37
# 2022 Population                         1.00             1.00
# 2020 Population                         1.00             1.00
# 2015 Population                         1.00             1.00
# 2010 Population                         1.00             1.00
# 2000 Population                         1.00             1.00
# 1990 Population                         0.99             1.00
# 1980 Population                         0.99             0.99
# 1970 Population                         0.99             0.99
# Area (km²)                              0.52             0.52
# Density (per km²)                      -0.04            -0.04
# Growth Rate                            -0.03            -0.04
# World Population Percentage             1.00             1.00
#
#                              2000 Population  1990 Population  \
# Rank                                   -0.35            -0.34
# 2022 Population                         1.00             0.99
# 2020 Population                         1.00             0.99
# 2015 Population                         1.00             0.99
# 2010 Population                         1.00             1.00
# 2000 Population                         1.00             1.00
# 1990 Population                         1.00             1.00
# 1980 Population                         1.00             1.00
# 1970 Population                         0.99             1.00
# Area (km²)                              0.52             0.52
# Density (per km²)                      -0.03            -0.03
# Growth Rate                            -0.05            -0.06
# World Population Percentage             1.00             0.99
#
#                              1980 Population  1970 Population  Area (km²)  \
# Rank                                   -0.33            -0.33       -0.38
# 2022 Population                         0.99             0.98        0.52
# 2020 Population                         0.99             0.98        0.52
# 2015 Population                         0.99             0.99        0.52
# 2010 Population                         0.99             0.99        0.52
# 2000 Population                         1.00             0.99        0.52
# 1990 Population                         1.00             1.00        0.52
# 1980 Population                         1.00             1.00        0.53
# 1970 Population                         1.00             1.00        0.54
# Area (km²)                              0.53             0.54        1.00
# Density (per km²)                      -0.03            -0.03       -0.07
# Growth Rate                            -0.08            -0.09       -0.01
# World Population Percentage             0.99             0.98        0.52
#
#                              Density (per km²)  Growth Rate  \
# Rank                                      0.13        -0.21
# 2022 Population                          -0.04        -0.01
# 2020 Population                          -0.04        -0.02
# 2015 Population                          -0.04        -0.03
# 2010 Population                          -0.04        -0.04
# 2000 Population                          -0.03        -0.05
# 1990 Population                          -0.03        -0.06
# 1980 Population                          -0.03        -0.08
# 1970 Population                          -0.03        -0.09
# Area (km²)                               -0.07        -0.01
# Density (per km²)                         1.00        -0.07
# Growth Rate                              -0.07         1.00
# World Population Percentage              -0.04        -0.01
#
#                              World Population Percentage
# Rank                                               -0.39
# 2022 Population                                     1.00
# 2020 Population                                     1.00
# 2015 Population                                     1.00
# 2010 Population                                     1.00
# 2000 Population                                     1.00
# 1990 Population                                     0.99
# 1980 Population                                     0.99
# 1970 Population                                     0.98
# Area (km²)                                          0.52
# Density (per km²)                                  -0.04
# Growth Rate                                        -0.01
# World Population Percentage                         1.00

# %%
sns.heatmap(df_num.corr(), annot=True)
plt.rcParams['figure.figsize']=(20,7)
plt.show()

# %%
df_nun=df.select_dtypes(include=[float, int])
df.groupby('Continent')[df_num.columns].mean().sort_values(by="2022 Population",ascending=True)
# Out:
#                 Rank  2022 Population  2020 Population  2015 Population  \
# Continent
# Oceania       187.00       2046386.32       1996157.00       1835704.05
# North America 161.71      15682571.45      15523631.84      14898137.58
# Europe        122.04      15811725.04      15875241.48      15785573.39
# Africa         91.85      26961948.00      25725500.10      22715954.10
# South America 107.25      29720074.00      29342410.67      27957079.33
# Asia           75.81      74014123.44      73166475.70      70203359.07
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Oceania             1685646.55       1418320.55       1214933.14
# North America      14173064.71      12687504.63      10989680.97
# Europe             15660596.24      15458519.15      15335326.54
# Africa             19975819.02      15558198.27      12158419.56
# South America      26628926.67      23832618.17      20399536.92
# Asia               66695706.81      59902972.09      52408451.47
#
#                1980 Population  1970 Population  Area (km²)  \
# Continent
# Oceania             1041272.18        884950.18   387028.27
# North America       9606051.66       8225963.82   637580.45
# Europe             14728110.76      13945879.17   488924.35
# Africa              9139807.92       6969879.85   561063.96
# South America      16700197.33      13390535.58  1314599.08
# Asia               43423636.49      35590784.79   647329.16
#
#                Density (per km²)  Growth Rate  World Population Percentage
# Continent
# Oceania                   136.78         1.01                         0.03
# North America             272.49         1.00                         0.20
# Europe                    706.24         1.00                         0.20
# Africa                    134.53         1.02                         0.34
# South America              18.11         1.01                         0.37
# Asia                     1129.50         1.01                         0.93

# %%
df[df['Continent'].str.contains('Oceania') ]
# Out:
#      Rank CCA3                   Country       Capital Continent  \
# 3     213  ASM            American Samoa     Pago Pago   Oceania
# 11     55  AUS                 Australia      Canberra   Oceania
# 44    223  COK              Cook Islands        Avarua   Oceania
# 66    162  FJI                      Fiji          Suva   Oceania
# 70    183  PYF          French Polynesia       Papeete   Oceania
# 81    191  GUM                      Guam       Hagåtña   Oceania
# 107   192  KIR                  Kiribati        Tarawa   Oceania
# 126   215  MHL          Marshall Islands        Majuro   Oceania
# 132   194  FSM                Micronesia       Palikir   Oceania
# 142   225  NRU                     Nauru         Yaren   Oceania
# 145   185  NCL             New Caledonia        Nouméa   Oceania
# 146   123  NZL               New Zealand    Wellington   Oceania
# 150   232  NIU                      Niue         Alofi   Oceania
# 153   210  NFK  Northern Mariana Islands        Saipan   Oceania
# 160    93  PNG          Papua New Guinea  Port Moresby   Oceania
# 179   188  WSM                     Samoa          Apia   Oceania
# 191   166  SLB           Solomon Islands       Honiara   Oceania
# 209   233  TKL                   Tokelau      Nukunonu   Oceania
# 210   197  TON                     Tonga    Nuku‘alofa   Oceania
# 216   227  TUV                    Tuvalu      Funafuti   Oceania
# 225   181  VUT                   Vanuatu     Port-Vila   Oceania
# 229   226  WLF         Wallis and Futuna      Mata-Utu   Oceania
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 3           44273.00         46189.00         51368.00         54849.00
# 11       26177413.00      25670051.00      23820236.00      22019168.00
# 44          17011.00         17029.00         17695.00         17212.00
# 66         929766.00        920422.00        917200.00        905169.00
# 70         306279.00        301920.00        291787.00        283788.00
# 81         171774.00        169231.00        167978.00        164905.00
# 107        131232.00        126463.00        116707.00        107995.00
# 126         41569.00         43413.00         49410.00         53416.00
# 132        114164.00        112106.00        109462.00        107588.00
# 142         12668.00         12315.00         11185.00         10241.00
# 145        289950.00        286403.00        283032.00        261426.00
# 146       5185288.00       5061133.00       4590590.00       4346338.00
# 150          1934.00          1942.00          1847.00          1812.00
# 153         49551.00         49587.00         51514.00         54087.00
# 160      10142619.00       9749640.00       8682174.00       7583269.00
# 179        222382.00        214929.00        203571.00        194672.00
# 191        724273.00        691191.00        612660.00        540394.00
# 209          1871.00          1827.00          1454.00          1367.00
# 210        106858.00        105254.00        106122.00        107383.00
# 216         11312.00         11069.00         10877.00         10550.00
# 225        326740.00        311685.00        276438.00        245453.00
# 229         11572.00         11655.00         12182.00         13142.00
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# 3           58230.00         47818.00         32886.00         27075.00
# 11       19017963.00      17048003.00      14706322.00      12595034.00
# 44          15897.00         17123.00         17651.00         20470.00
# 66         832509.00        780430.00        644582.00        527634.00
# 70         250927.00        211089.00        163591.00        117891.00
# 81         160188.00        138263.00        110286.00         88300.00
# 107         88826.00         75124.00         60813.00         57437.00
# 126         54224.00         46047.00         31988.00         23969.00
# 132        111709.00         98603.00         76299.00         58989.00
# 142         10377.00          9598.00          7635.00          6663.00
# 145        221537.00        177264.00        148599.00        110982.00
# 146       3855266.00       3397389.00       3147168.00       2824061.00
# 150          2074.00          2533.00          3637.00          5185.00
# 153         80338.00         48002.00         17613.00         10143.00
# 160       5508297.00       3864972.00       3104788.00       2489059.00
# 179        184008.00        168186.00        164905.00        142771.00
# 191        429978.00        324171.00        233668.00        172833.00
# 209          1666.00          1669.00          1647.00          1714.00
# 210        102603.00         98727.00         96708.00         86484.00
# 216          9638.00          9182.00          7731.00          5814.00
# 225        192074.00        150882.00        118156.00         87019.00
# 229         14723.00         13454.00         11315.00          9377.00
#
#      Area (km²)  Density (per km²)  Growth Rate  World Population Percentage
# 3        199.00             222.48         0.98                         0.00
# 11   7692024.00               3.40         1.01                         0.33
# 44       236.00              72.08         1.00                         0.00
# 66     18272.00              50.88         1.01                         0.01
# 70      4167.00              73.50         1.01                         0.00
# 81       549.00             312.89         1.01                         0.00
# 107      811.00             161.81         1.02                         0.00
# 126      181.00             229.66         0.99                         0.00
# 132      702.00             162.63         1.01                         0.00
# 142       21.00             603.24         1.01                         0.00
# 145    18575.00              15.61         1.01                         0.00
# 146   270467.00              19.17         1.01                         0.07
# 150      260.00               7.44         1.00                         0.00
# 153      464.00             106.79         1.00                         0.00
# 160   462840.00              21.91         1.02                         0.13
# 179     2842.00              78.25         1.02                         0.00
# 191    28896.00              25.06         1.02                         0.01
# 209       12.00             155.92         1.01                         0.00
# 210      747.00             143.05         1.01                         0.00
# 216       26.00             435.08         1.01                         0.00
# 225    12189.00              26.81         1.02                         0.00
# 229      142.00              81.49         1.00                         0.00

# %%
df2= df.groupby('Continent')[['1970 Population',
       '1980 Population', '1990 Population', '2000 Population',
       '2010 Population', '2015 Population', '2020 Population',
       '2022 Population']].mean().sort_values(by='2022 Population',ascending=False)
df2
# Out:
#                1970 Population  1980 Population  1990 Population  \
# Continent
# Asia               35590784.79      43423636.49      52408451.47
# South America      13390535.58      16700197.33      20399536.92
# Africa              6969879.85       9139807.92      12158419.56
# Europe             13945879.17      14728110.76      15335326.54
# North America       8225963.82       9606051.66      10989680.97
# Oceania              884950.18       1041272.18       1214933.14
#
#                2000 Population  2010 Population  2015 Population  \
# Continent
# Asia               59902972.09      66695706.81      70203359.07
# South America      23832618.17      26628926.67      27957079.33
# Africa             15558198.27      19975819.02      22715954.10
# Europe             15458519.15      15660596.24      15785573.39
# North America      12687504.63      14173064.71      14898137.58
# Oceania             1418320.55       1685646.55       1835704.05
#
#                2020 Population  2022 Population
# Continent
# Asia               73166475.70      74014123.44
# South America      29342410.67      29720074.00
# Africa             25725500.10      26961948.00
# Europe             15875241.48      15811725.04
# North America      15523631.84      15682571.45
# Oceania             1996157.00       2046386.32

# %%
df3=df2.T

# %%
df3.plot()
# Out:
# <Axes: >

# %%
df.boxplot(figsize=(20,10))
# Out:
# <Axes: >

# %%
df.select_dtypes(include='float')
# Out:
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0        41128771.00      38972230.00      33753499.00      28189672.00
# 1         2842321.00       2866849.00       2882481.00       2913399.00
# 2        44903225.00      43451666.00      39543154.00      35856344.00
# 3           44273.00         46189.00         51368.00         54849.00
# 4           79824.00         77700.00         71746.00         71519.00
# ..               ...              ...              ...              ...
# 228      98186856.00      96648685.00      92191398.00      87411012.00
# 229         11572.00         11655.00         12182.00         13142.00
# 230        575986.00        556048.00        491824.00        413296.00
# 231      33696614.00      32284046.00      28516545.00      24743946.00
# 233      16320537.00      15669666.00      14154937.00      12839771.00
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# 0        19542982.00      10694796.00      12486631.00      10752971.00
# 1         3182021.00       3295066.00       2941651.00       2324731.00
# 2        30774621.00      25518074.00      18739378.00      13795915.00
# 3           58230.00         47818.00         32886.00         27075.00
# 4           66097.00         53569.00         35611.00         19860.00
# ..               ...              ...              ...              ...
# 228      79001142.00      66912613.00      52968270.00      41928849.00
# 229         14723.00         13454.00         11315.00          9377.00
# 230        270375.00        178529.00        116775.00         76371.00
# 231      18628700.00      13375121.00       9204938.00       6843607.00
# 233      11834676.00      10113893.00       7049926.00       5202918.00
#
#      Area (km²)  Density (per km²)  Growth Rate  World Population Percentage
# 0     652230.00              63.06         1.03                         0.52
# 1      28748.00              98.87         1.00                         0.04
# 2    2381741.00              18.85         1.02                         0.56
# 3        199.00             222.48         0.98                         0.00
# 4        468.00             170.56         1.01                         0.00
# ..          ...                ...          ...                          ...
# 228   331212.00             296.45         1.01                         1.23
# 229      142.00              81.49         1.00                         0.00
# 230   266000.00               2.17         1.02                         0.01
# 231   527968.00              63.82         1.02                         0.42
# 233   390757.00              41.77         1.02                         0.20
#
# [209 rows x 12 columns]
